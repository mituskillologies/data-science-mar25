# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5, 2, 0.5)
x
# Out:
# array([-5. , -4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,
#         0.5,  1. ,  1.5])

# %%
y = 112 * x + 100
y
# Out:
# array([-460., -404., -348., -292., -236., -180., -124.,  -68.,  -12.,
#          44.,  100.,  156.,  212.,  268.])

# %%
plt.plot(x, y);
