# %%
# data => movies.csv
# location => https://mitu.co.in/dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("movies.csv")
df.head()
# Out:
#                      Movie     Budget  Celebrities             Class
# 0            The 400 Blows  100000000          2.0  Box Office Burst
# 1                La Haine   210000000          3.0  Box Office Burst
# 2            The Godfather  250000000          4.0  Box Office Burst
# 3  The Godfather: Part II   350000000          2.0  Box Office Burst
# 4           Man Bites Dog   400600000          4.0  Box Office Burst

# %%
df.shape
# Out:
# (30, 4)

# %%
sns.jointplot(x = 'Budget', y = 'Celebrities', data = df, hue = 'Class');

# %%
# separate the input and output data

x = df[["Budget", 'Celebrities']]  # input
y = df["Class"]

# %%
# build the model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(random_state= 42)

# %%
clf.fit(x, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# predict -> 1. 5000000 2              2. 5000000  10

# %%
clf.predict([[5000000, 2], [5000000, 10]])
# Out:
# C:\Program Files\Orange\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Box Office Burst', 'Critical Success'], dtype=object)
